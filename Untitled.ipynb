# %%
import pandas

# %%
segment_fact = pandas.read_excel('fly_2.xlsx', 'Segment_Fact')
flight_dim = pandas.read_excel('fly_2.xlsx', 'Flight_Dim')
date_dim = pandas.read_excel('fly_2.xlsx', 'Date_Dim')

# %%
# Out:
#     FlightKey CityPair        OriginAirport  OriginAirportId     OriginCity  \
# 0           1   BKK-LA       Elisse Airport                4         LA,USA
# 1           2   BKK-LN       London Airport                7          LN,UK
# 2           3  BKK-SIN       Changi Airport                8  SIN,Singapore
# 3           4    KK-LA      Konkhen Airport               11    KK,Thailand
# 4           5   BJ-BKK  Suvannapoom Airport                2   BKK,Thailand
# 5           6    BJ-LN       London Airport                7          LN,UK
# 6           7  BKK-FJP  Suvannapoom Airport                2   BKK,Thailand
# 7           8   BJ-FJP      Beijing Airport                5       BJ,China
# 8           9   CM-FJP    Chiangmai Airport               10    CM,Thailand
# 9          10   FJP-KK      Konkhen Airport               11    KK,Thailand
# 10         11    BJ-LN      Beijing Airport                5       BJ,China
# ...
