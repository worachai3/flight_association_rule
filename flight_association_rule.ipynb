# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
segment_fact = pd.read_excel('fly_2.xlsx', 'Segment_Fact')
flight_dim = pd.read_excel('fly_2.xlsx', 'Flight_Dim')
date_dim = pd.read_excel('fly_2.xlsx', 'Date_Dim')

# %%
segment_flight = segment_fact.set_index('FlightKey').join(flight_dim.set_index('FlightKey'))

# %%
data = segment_flight.set_index('ScheduledDepartureDateKey').join(date_dim.set_index('DateKey'))

# %%
data = data[['FrequentFlyerProfileKey', 'DestinationCity', 'CalQuarter']]
data
# Out:
#      FrequentFlyerProfileKey DestinationCity  CalQuarter
# 123                       21       FJP,Japan           2
# 123                       21       FJP,Japan           2
# 125                       39     KK,Thailand           2
# 125                       46     KK,Thailand           2
# 125                       51     KK,Thailand           2
# 131                       25           LN,UK           2
# 136                        1        BJ,China           2
# 136                       22        BJ,China           2
# 136                       22        BJ,China           2
# 136                       41        BJ,China           2
# 138                       13          LA,USA           2
# 138                       44          LA,USA           2
# 138                       49          LA,USA           2
# 144                       54       FJP,Japan           2
# 151                       51    BKK,Thailand           2
# ...

# %%
table = pd.pivot_table(data, 'CalQuarter', ['FrequentFlyerProfileKey'], ['DestinationCity'])

# %%
table
# Out:
# DestinationCity          BJ,China  BKK,Thailand  CM,Thailand  FJP,Japan  \
# FrequentFlyerProfileKey
# 1                             2.0           NaN          NaN        NaN
# 2                             3.0           NaN          NaN        NaN
# 3                             NaN           NaN          NaN        2.0
# 4                             NaN           NaN          NaN        3.0
# 5                             NaN           NaN          NaN        3.0
# 6                             3.0           NaN          NaN        NaN
# 7                             3.0           NaN          NaN        NaN
# 8                             NaN           NaN          3.0        NaN
# 9                             NaN           NaN          3.0        3.0
# 10                            NaN           NaN          NaN        3.0
# 11                            NaN           3.0          3.0        NaN
# 12                            NaN           NaN          NaN        3.0
# ...
