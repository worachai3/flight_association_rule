# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
segment_fact = pd.read_excel('fly_2.xlsx', 'Segment_Fact')
flight_dim = pd.read_excel('fly_2.xlsx', 'Flight_Dim')
date_dim = pd.read_excel('fly_2.xlsx', 'Date_Dim')

# %%
segment_flight = segment_fact.set_index('FlightKey').join(flight_dim.set_index('FlightKey'))

# %%
data = segment_flight.set_index('ScheduledDepartureDateKey').join(date_dim.set_index('DateKey'))

# %%
data = data[['FrequentFlyerKey', 'DestinationCity', 'CalQuarter']]

# %%
# Out:
#      FrequentFlyerKey DestinationCity  CalQuarter
# 123                21       FJP,Japan           2
# 123                21       FJP,Japan           2
# 125                16     KK,Thailand           2
# 125                 1     KK,Thailand           2
# 125                 4     KK,Thailand           2
# 131                 2           LN,UK           2
# 136                 1        BJ,China           2
# 136                 1        BJ,China           2
# 136                 1        BJ,China           2
# 136                 6        BJ,China           2
# 138                 3          LA,USA           2
# 138                 9          LA,USA           2
# 138                17          LA,USA           2
# 144                22       FJP,Japan           2
# 151                 4    BKK,Thailand           2
# 152                21     CM,Thailand           2
# 152                21     CM,Thailand           2
# 152                 1     CM,Thailand           2
# 152                 2     CM,Thailand           2
# 152                17     CM,Thailand           2
# 153                21     KK,Thailand           2
# 163                 1           LN,UK           2
# 163                 3           LN,UK           2
# 164                12       FJP,Japan           2
# 164                 1       FJP,Japan           2
# 167                17       FJP,Japan           2
# 167                 9       FJP,Japan           2
# 167                 5       FJP,Japan           2
# 167                17       FJP,Japan           2
# 175                17       FJP,Japan           2
# 175                 4       FJP,Japan           2
# 177                 3     CM,Thailand           2
# 177                17     CM,Thailand           2
# 177                 1     CM,Thailand           2
# 178                12           LN,UK           2
# 178                17           LN,UK           2
# 213                 8       FJP,Japan           3
# 213                21       FJP,Japan           3
# 213                21       FJP,Japan           3
# 214                15     CM,Thailand           3
# 214                20     CM,Thailand           3
# 214                20     CM,Thailand           3
# 215                 1     KK,Thailand           3
# 215                 2     KK,Thailand           3
# 215                 4     KK,Thailand           3
# 215                 7     KK,Thailand           3
# 215                 8     KK,Thailand           3
# 215                 8     KK,Thailand           3
# 215                10     KK,Thailand           3
# 215                16     KK,Thailand           3
# ..                ...             ...         ...
# 242                17     CM,Thailand           3
# 242                17     CM,Thailand           3
# 242                20     CM,Thailand           3
# 242                21     CM,Thailand           3
# 242                21     CM,Thailand           3
# 243                21     KK,Thailand           3
# 253                 1           LN,UK           3
# 253                 3           LN,UK           3
# 253                21           LN,UK           3
# 254                 1       FJP,Japan           3
# 254                 9       FJP,Japan           3
# 254                12       FJP,Japan           3
# 254                19       FJP,Japan           3
# 256                 6    BKK,Thailand           3
# 256                20    BKK,Thailand           3
# 256                 6       FJP,Japan           3
# 257                 3       FJP,Japan           3
# 257                 5       FJP,Japan           3
# 257                 8       FJP,Japan           3
# 257                 9       FJP,Japan           3
# 257                10       FJP,Japan           3
# 257                17       FJP,Japan           3
# 257                17       FJP,Japan           3
# 257                22       FJP,Japan           3
# 265                 9    BKK,Thailand           3
# 265                21    BKK,Thailand           3
# 265                 4       FJP,Japan           3
# 265                 4       FJP,Japan           3
# 265                11       FJP,Japan           3
# 265                17       FJP,Japan           3
# 265                18       FJP,Japan           3
# 265                20       FJP,Japan           3
# 265                22       FJP,Japan           3
# 265                22       FJP,Japan           3
# 267                 1     CM,Thailand           3
# 267                 3     CM,Thailand           3
# 267                 3     CM,Thailand           3
# 267                 6     CM,Thailand           3
# 267                 9     CM,Thailand           3
# 267                17     CM,Thailand           3
# 267                18     CM,Thailand           3
# 267                21     CM,Thailand           3
# 268                 2           LN,UK           3
# 268                 2           LN,UK           3
# 268                10           LN,UK           3
# 268                12           LN,UK           3
# 268                17           LN,UK           3
# 268                20           LN,UK           3
# 268                21           LN,UK           3
# 268                21           LN,UK           3
#
# [138 rows x 3 columns]
